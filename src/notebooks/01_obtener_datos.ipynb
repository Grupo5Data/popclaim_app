# %%
## Importamos las librerias necesarias

# Para hacer las requests a la API
import requests

# Para guardar los tokens de acceso de la API
import os

#Para manejar los json que sacamos de la API
import json

import pandas as pd
import csv

# Para parsear a un formato legible los datos de fecha que sacamos de la API
import dateutil.parser

# %%
## para poder ver el texto entero en la columna del dataframe
pd.set_option("display.max_colwidth", None)

# %%
## sustituir <bearer_token> por nuestro bearer_token personal y ejecutar la celda
## una vez ejecutada se puede borrar, ya que en la siguiente celda se va a recuperar el token del entorno
## y así ya no se queda visible
# os.environ['TOKEN'] = '<bearer_token>'

# %%
## ahora creamos nuestra función auth() que recupera el TOKEN del entorno
def auth():
    return os.getenv('TOKEN')

# %%
## creamos una función que coje nuestro bearer token, lo pasa para la autorización y retorna unos HEADERS que usaremos para acceder a la API
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
## ahora que podemos acceder a la API, construimos la request para el "endpoint" que vamos a usar y los parámetros que queremos pasar
def create_url(keyword, max_results = 10):
    
    search_url = "https://api.twitter.com/2/tweets/search/recent"   ## "recent search" baja los tweets de los últimos 7 días
    
    query_params = {'query': keyword,
                'max_results': max_results,
                'expansions': 'attachments.poll_ids,attachments.media_keys,author_id,entities.mentions.username,geo.place_id,in_reply_to_user_id,referenced_tweets.id,referenced_tweets.id.author_id',
                'media.fields': 'duration_ms,height,media_key,preview_image_url,type,url,width,public_metrics,alt_text',
                'place.fields': 'contained_within,country,country_code,full_name,geo,id,name,place_type',
                'tweet.fields': 'attachments,author_id,context_annotations,conversation_id,created_at,entities,geo,id,in_reply_to_user_id,lang,public_metrics,possibly_sensitive,referenced_tweets,reply_settings,source,text,withheld',
                'user.fields': 'created_at,description,entities,id,location,name,pinned_tweet_id,profile_image_url,protected,public_metrics,url,username,verified,withheld',
                'next_token': {}}
    return (search_url, query_params)

# %%
## nos conectamos al endpoint, ahora que tenemos url, headers y los parametros que queremos
## La función mandará la request GET, si todo sale bien (response code 200), retornará la response en formato json
## NOTA: "next_token" está como None por defecto ya que solo queremos saber si existe
def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
# ## creamos la request, vamos a definir los inputs (los que nos interesa sacar de twitter)

bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "samsung lang:es"   ##tweets en español que contengan la palabra "samsung"
max_results = 100   ## según los permisos que tenemos, no se pueden bajar más de 100 a la vez


## ahora creamos la URL y tendremos el response de la API (en formato json). Si todo está correcto saldrá el código 200
url = create_url(keyword, max_results)
json_response = connect_to_endpoint(url[0], headers, url[1])
# Out:
# Endpoint Response Code: 200

# %%
## ahora imprimimos el response en formato json
print(json.dumps(json_response, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "author_id": "1168319786864054272",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "10026364281",
#                         "name": "Apple"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "1174344555111469057",
#                         "name": "Samsung Indonesia"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "10026364234",
#                         "name": "Samsung "
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10045298641",
#                         "name": "Samsung USA"
#                     }
#                 }
#             ],
#             "conversation_id": "1483798412088647689",
#             "created_at": "2022-01-19T13:48:03.000Z",
#             "entities": {
#                 "annotations": [
#                     {
#                         "end": 137,
#                         "normalized_text": "Samsung",
#                         "probability": 0.7718,
#                         "start": 131,
#                         "type": "Product"
#                     },
#                     {
#                         "end": 145,
#                         "normalized_text": "Apple",
#                         "probability": 0.5458,
#                         "start": 141,
#                         "type": "Product"
#                     }
#                 ]
#             },
#             "id": "1483798412088647689",
#             "lang": "es",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "Oye pero ira a funcionar la ley de tallas? Si mal no estoy, hab\u00eda una norma que prohib\u00eda vender celulares sin cargador, y ah\u00ed esta Samsung y Apple haci\u00e9ndolo, igual que la ley que prohib\u00eda vender celulares sin radio y tambi\u00e9n se venden xd"
#         },
#         {
#             "attachments": {
#                 "media_keys": [
#                     "3_1483798229187768320"
#                 ]
#             },
#             "author_id": "1276521905475006467",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "1174344555111469057",
#                         "name": "Samsung Indonesia"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "10026364234",
#                         "name": "Samsung "
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10026230384",
#                         "name": "Samsung Galaxy"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10026331316",
#                         "name": "Samsung Mobile"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10045298641",
#                         "name": "Samsung USA"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "The specific model or version of a product.  Examples: Audi A8, Ben & Jerry's Chocolate Chip Ice Cream",
#                         "id": "49",
#                         "name": "Product Version"
#                     },
#                     "entity": {
#                         "id": "10040464729",
#                         "name": "Samsung Mobile UK"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "The specific model or version of a product.  Examples: Audi A8, Ben & Jerry's Chocolate Chip Ice Cream",
#                         "id": "49",
#                         "name": "Product Version"
#                     },
#                     "entity": {
#                         "id": "10041364617",
#                         "name": "Samsung Mobile US"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Top level interests and hobbies groupings, like Food or Travel",
#                         "id": "65",
#                         "name": "Interests and Hobbies Vertical"
#                     },
#                     "entity": {
#                         "description": "Technology and computing",
#                         "id": "848920371311001600",
#                         "name": "Technology"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A grouping of interests and hobbies entities, like Novelty Food or Destinations",
#                         "id": "66",
#                         "name": "Interests and Hobbies Category"
#                     },
#                     "entity": {
#                         "description": "Cell phones",
#                         "id": "848920700073123840",
#                         "name": "Cell Phones"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Entity Service top level domain, every item that is in Entity Service should be in this domain",
#                         "id": "30",
#                         "name": "Entities [Entity Service]"
#                     },
#                     "entity": {
#                         "description": "Mobile",
#                         "id": "848985956778561538",
#                         "name": "Mobile"
#                     }
#                 }
#             ],
#             "conversation_id": "1483798231293300738",
#             "created_at": "2022-01-19T13:47:20.000Z",
#             "entities": {
#                 "annotations": [
#                     {
#                         "end": 43,
#                         "normalized_text": "Samsung Galaxy A22",
#                         "probability": 0.9304,
#                         "start": 26,
#                         "type": "Product"
#                     }
#                 ],
#                 "hashtags": [
#                     {
#                         "end": 99,
#                         "start": 93,
#                         "tag": "Publi"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "pic.twitter.com/eyvPwsIabt",
#                         "end": 151,
#                         "expanded_url": "https://twitter.com/rebajazos/status/1483798231293300738/photo/1",
#                         "start": 128,
#                         "url": "https://t.co/eyvPwsIabt"
#                     }
#                 ]
#             },
#             "id": "1483798231293300738",
#             "lang": "es",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Integromat",
#             "text": "\ud83c\udfaf Super precio top en el Samsung Galaxy A22 que tienes opci\u00f3n de financiar hasta en 10 meses #Publi\n\n\u2b55\ufe0f Ahora: 184,00\u20ac \n\ud83d\uded2 Aqu\u00ed: https://t.co/eyvPwsIabt"
#         },
#         {
#             "attachments": {
#                 "media_keys": [
#                     "3_1483798226176258051"
#                 ]
#             },
#             "author_id": "807986023624015872",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "1174344555111469057",
#                         "name": "Samsung Indonesia"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "10026364234",
#                         "name": "Samsung "
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10026230384",
#                         "name": "Samsung Galaxy"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10026331316",
#                         "name": "Samsung Mobile"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10045298641",
#                         "name": "Samsung USA"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "The specific model or version of a product.  Examples: Audi A8, Ben & Jerry's Chocolate Chip Ice Cream",
#                         "id": "49",
#                         "name": "Product Version"
#                     },
#                     "entity": {
#                         "id": "10040464729",
#                         "name": "Samsung Mobile UK"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "The specific model or version of a product.  Examples: Audi A8, Ben & Jerry's Chocolate Chip Ice Cream",
#                         "id": "49",
#                         "name": "Product Version"
#                     },
#                     "entity": {
#                         "id": "10041364617",
#                         "name": "Samsung Mobile US"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Top level interests and hobbies groupings, like Food or Travel",
#                         "id": "65",
#                         "name": "Interests and Hobbies Vertical"
#                     },
#                     "entity": {
#                         "description": "Technology and computing",
#                         "id": "848920371311001600",
#                         "name": "Technology"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A grouping of interests and hobbies entities, like Novelty Food or Destinations",
#                         "id": "66",
#                         "name": "Interests and Hobbies Category"
#                     },
#                     "entity": {
#                         "description": "Cell phones",
#                         "id": "848920700073123840",
#                         "name": "Cell Phones"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Entity Service top level domain, every item that is in Entity Service should be in this domain",
#                         "id": "30",
#                         "name": "Entities [Entity Service]"
#                     },
#                     "entity": {
#                         "description": "Mobile",
#                         "id": "848985956778561538",
#                         "name": "Mobile"
#                     }
#                 }
#             ],
#             "conversation_id": "1483798227799392259",
#             "created_at": "2022-01-19T13:47:19.000Z",
#             "entities": {
#                 "annotations": [
#                     {
#                         "end": 43,
#                         "normalized_text": "Samsung Galaxy A22",
#                         "probability": 0.9304,
#                         "start": 26,
#                         "type": "Product"
#                     }
#                 ],
#                 "hashtags": [
#                     {
#                         "end": 99,
#                         "start": 93,
#                         "tag": "Publi"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "pic.twitter.com/ZsSEIqLQ8j",
#                         "end": 151,
#                         "expanded_url": "https://twitter.com/Ofertapremium/status/1483798227799392259/photo/1",
#                         "start": 128,
#                         "url": "https://t.co/ZsSEIqLQ8j"
#                     }
#                 ]
#             },
#             "id": "1483798227799392259",
#             "lang": "es",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Integromat",
#             "text": "\ud83c\udfaf Super precio top en el Samsung Galaxy A22 que tienes opci\u00f3n de financiar hasta en 10 meses #Publi\n\n\u2b55\ufe0f Ahora: 184,00\u20ac \n\ud83d\uded2 Aqu\u00ed: https://t.co/ZsSEIqLQ8j"
#         },
#         {
#             "attachments": {
#                 "media_keys": [
#                     "3_1483798223059828741"
#                 ]
#             },
#             "author_id": "2540707132",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "1174344555111469057",
#                         "name": "Samsung Indonesia"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "10026364234",
#                         "name": "Samsung "
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10026230384",
#                         "name": "Samsung Galaxy"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10026331316",
#                         "name": "Samsung Mobile"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10045298641",
#                         "name": "Samsung USA"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "The specific model or version of a product.  Examples: Audi A8, Ben & Jerry's Chocolate Chip Ice Cream",
#                         "id": "49",
#                         "name": "Product Version"
#                     },
#                     "entity": {
#                         "id": "10040464729",
#                         "name": "Samsung Mobile UK"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "The specific model or version of a product.  Examples: Audi A8, Ben & Jerry's Chocolate Chip Ice Cream",
#                         "id": "49",
#                         "name": "Product Version"
#                     },
#                     "entity": {
#                         "id": "10041364617",
#                         "name": "Samsung Mobile US"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Top level interests and hobbies groupings, like Food or Travel",
#                         "id": "65",
#                         "name": "Interests and Hobbies Vertical"
#                     },
#                     "entity": {
#                         "description": "Technology and computing",
#                         "id": "848920371311001600",
#                         "name": "Technology"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A grouping of interests and hobbies entities, like Novelty Food or Destinations",
#                         "id": "66",
#                         "name": "Interests and Hobbies Category"
#                     },
#                     "entity": {
#                         "description": "Cell phones",
#                         "id": "848920700073123840",
#                         "name": "Cell Phones"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Entity Service top level domain, every item that is in Entity Service should be in this domain",
#                         "id": "30",
#                         "name": "Entities [Entity Service]"
#                     },
#                     "entity": {
#                         "description": "Mobile",
#                         "id": "848985956778561538",
#                         "name": "Mobile"
#                     }
#                 }
#             ],
#             "conversation_id": "1483798224704004097",
#             "created_at": "2022-01-19T13:47:19.000Z",
#             "entities": {
#                 "annotations": [
#                     {
#                         "end": 43,
#                         "normalized_text": "Samsung Galaxy A22",
#                         "probability": 0.9304,
#                         "start": 26,
#                         "type": "Product"
#                     }
#                 ],
#                 "hashtags": [
#                     {
#                         "end": 99,
#                         "start": 93,
#                         "tag": "Publi"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "pic.twitter.com/1u2H9MtKGd",
#                         "end": 151,
#                         "expanded_url": "https://twitter.com/Cholloterapia/status/1483798224704004097/photo/1",
#                         "start": 128,
#                         "url": "https://t.co/1u2H9MtKGd"
#                     }
#                 ]
#             },
#             "id": "1483798224704004097",
#             "lang": "es",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Integromat",
#             "text": "\ud83c\udfaf Super precio top en el Samsung Galaxy A22 que tienes opci\u00f3n de financiar hasta en 10 meses #Publi\n\n\u2b55\ufe0f Ahora: 184,00\u20ac \n\ud83d\uded2 Aqu\u00ed: https://t.co/1u2H9MtKGd"
#         },
#         {
#             "attachments": {
#                 "media_keys": [
#                     "3_1483797672855326726"
#                 ]
#             },
#             "author_id": "4038730750",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "1174344555111469057",
#                         "name": "Samsung Indonesia"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "10026364234",
#                         "name": "Samsung "
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10045298641",
#                         "name": "Samsung USA"
#                     }
#                 }
#             ],
#             "conversation_id": "1483797675447361541",
#             "created_at": "2022-01-19T13:45:08.000Z",
#             "entities": {
#                 "annotations": [
#                     {
#                         "end": 81,
#                         "normalized_text": "Samsung EP-TA800NBEGEU - Cargador de Pared 25W USB-C, Color Negro",
#                         "probability": 0.3136,
#                         "start": 17,
#                         "type": "Product"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "amazon.es/Samsung-EP-TA8\u2026",
#                         "end": 129,
#                         "expanded_url": "https://www.amazon.es/Samsung-EP-TA800NBEGEU-Cargador-Pared-USB-C/dp/B08P95B5FR/?tag=ahorroamazon-21",
#                         "start": 106,
#                         "url": "https://t.co/kMo1FMczst"
#                     },
#                     {
#                         "display_url": "pic.twitter.com/t8I70uU7Fh",
#                         "end": 153,
#                         "expanded_url": "https://twitter.com/Ahorro_Amazon/status/1483797675447361541/photo/1",
#                         "start": 130,
#                         "url": "https://t.co/t8I70uU7Fh"
#                     }
#                 ]
#             },
#             "id": "1483797675447361541",
#             "lang": "es",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "AhorraEnAmazon",
#             "text": "\u00a1YA TIENES PLAN! Samsung EP-TA800NBEGEU - Cargador de Pared 25W USB-C, Color Negro   por (OJO) 17,47\u00a0\u20ac\u20ac   https://t.co/kMo1FMczst https://t.co/t8I70uU7Fh"
#         },
#         {
#             "author_id": "714759003281207296",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "1174344555111469057",
#                         "name": "Samsung Indonesia"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "10026364234",
#                         "name": "Samsung "
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10026230384",
#                         "name": "Samsung Galaxy"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10026331316",
#                         "name": "Samsung Mobile"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10045298641",
#                         "name": "Samsung USA"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "The specific model or version of a product.  Examples: Audi A8, Ben & Jerry's Chocolate Chip Ice Cream",
#                         "id": "49",
#                         "name": "Product Version"
#                     },
#                     "entity": {
#                         "description": "Samsung Galaxy S8",
#                         "id": "10026415838",
#                         "name": "Samsung Galaxy S8"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "The specific model or version of a product.  Examples: Audi A8, Ben & Jerry's Chocolate Chip Ice Cream",
#                         "id": "49",
#                         "name": "Product Version"
#                     },
#                     "entity": {
#                         "id": "10040464729",
#                         "name": "Samsung Mobile UK"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "The specific model or version of a product.  Examples: Audi A8, Ben & Jerry's Chocolate Chip Ice Cream",
#                         "id": "49",
#                         "name": "Product Version"
#                     },
#                     "entity": {
#                         "id": "10041364617",
#                         "name": "Samsung Mobile US"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Top level interests and hobbies groupings, like Food or Travel",
#                         "id": "65",
#                         "name": "Interests and Hobbies Vertical"
#                     },
#                     "entity": {
#                         "description": "Technology and computing",
#                         "id": "848920371311001600",
#                         "name": "Technology"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A grouping of interests and hobbies entities, like Novelty Food or Destinations",
#                         "id": "66",
#                         "name": "Interests and Hobbies Category"
#                     },
#                     "entity": {
#                         "description": "Cell phones",
#                         "id": "848920700073123840",
#                         "name": "Cell Phones"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Entity Service top level domain, every item that is in Entity Service should be in this domain",
#                         "id": "30",
#                         "name": "Entities [Entity Service]"
#                     },
#                     "entity": {
#                         "description": "Mobile",
#                         "id": "848985956778561538",
#                         "name": "Mobile"
#                     }
#                 }
#             ],
#             "conversation_id": "1483797327571734533",
#             "created_at": "2022-01-19T13:43:45.000Z",
#             "entities": {
#                 "annotations": [
#                     {
#                         "end": 6,
#                         "normalized_text": "Samsung",
#                         "probability": 0.6235,
#                         "start": 0,
#                         "type": "Organization"
#                     },
#                     {
#                         "end": 68,
#                         "normalized_text": "Samsung Galaxy Tab S8",
#                         "probability": 0.8845,
#                         "start": 48,
#                         "type": "Product"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "description": "Samsung ha publicado por error una imagen de la Samsung Galaxy Tab S8 donde podemos ver el dise\u00f1o que tendr\u00e1, incluido el notch de su pantalla.",
#                         "display_url": "as.com/meristation/20\u2026",
#                         "end": 167,
#                         "expanded_url": "https://as.com/meristation/2022/01/19/betech/1642595950_725321.html?utm_term=Autofeed&utm_medium=Social&ssm=CM_BT_TW&utm_source=Twitter#Echobox=1642597337",
#                         "images": [
#                             {
#                                 "height": 675,
#                                 "url": "https://pbs.twimg.com/news_img/1483797330616799243/ac8PHP6c?format=jpg&name=orig",
#                                 "width": 1200
#                             },
#                             {
#                                 "height": 150,
#                                 "url": "https://pbs.twimg.com/news_img/1483797330616799243/ac8PHP6c?format=jpg&name=150x150",
#                                 "width": 150
#                             }
#                         ],
#                         "start": 144,
#                         "status": 200,
#                         "title": "Este ser\u00e1 el dise\u00f1o de la Samsung Galaxy Tab S8, con notch incluido",
#                         "unwound_url": "https://as.com/meristation/2022/01/19/betech/1642595950_725321.html?utm_term=Autofeed&utm_medium=Social&ssm=CM_BT_TW&utm_source=Twitter#Echobox=1642597337",
#                         "url": "https://t.co/y4EBPPOaZt"
#                     }
#                 ]
#             },
#             "id": "1483797327571734533",
#             "lang": "es",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Echobox",
#             "text": "Samsung ha publicado por error una imagen de la Samsung Galaxy Tab S8 donde podemos ver el dise\u00f1o que tendr\u00e1, incluido el notch de su pantalla. https://t.co/y4EBPPOaZt"
#         },
#         {
#             "author_id": "1076383362250690560",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "1174344555111469057",
#                         "name": "Samsung Indonesia"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "10026364234",
#                         "name": "Samsung "
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10045298641",
#                         "name": "Samsung USA"
#                     }
#                 }
#             ],
#             "conversation_id": "1483597236730740740",
#             "created_at": "2022-01-19T13:42:19.000Z",
#             "entities": {
#                 "annotations": [
#                     {
#                         "end": 37,
#                         "normalized_text": "Samsung NOTE 7",
#                         "probability": 0.9598,
#                         "start": 24,
#                         "type": "Product"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "end": 11,
#                         "id": "413587342",
#                         "start": 0,
#                         "username": "Shadow_swt"
#                     }
#                 ]
#             },
#             "id": "1483796969625694213",
#             "in_reply_to_user_id": "413587342",
#             "lang": "es",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1483597236730740740",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@Shadow_swt C\u00f3mprate un Samsung NOTE 7, son lo mismo pr\u00e1cticamente."
#         },
#         {
#             "author_id": "1429529658996011009",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Top level entities that describe a Brands industry",
#                         "id": "45",
#                         "name": "Brand Vertical"
#                     },
#                     "entity": {
#                         "id": "781974597302226944",
#                         "name": "Transportation"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "1174344555111469057",
#                         "name": "Samsung Indonesia"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Top level entities that describe a Brands industry",
#                         "id": "45",
#                         "name": "Brand Vertical"
#                     },
#                     "entity": {
#                         "id": "781972125171060736",
#                         "name": "Auto"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Categories within Brand Verticals that narrow down the scope of Brands",
#                         "id": "46",
#                         "name": "Brand Category"
#                     },
#                     "entity": {
#                         "id": "781972125179518977",
#                         "name": "Auto Manufacturer"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "10026295477",
#                         "name": "Toyota"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "10026364234",
#                         "name": "Samsung "
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10045298641",
#                         "name": "Samsung USA"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Top level interests and hobbies groupings, like Food or Travel",
#                         "id": "65",
#                         "name": "Interests and Hobbies Vertical"
#                     },
#                     "entity": {
#                         "description": "Hobbies and interests",
#                         "id": "847868745150119936",
#                         "name": "Home & family"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A grouping of interests and hobbies entities, like Novelty Food or Destinations",
#                         "id": "66",
#                         "name": "Interests and Hobbies Category"
#                     },
#                     "entity": {
#                         "description": "Car culture",
#                         "id": "847528391163092993",
#                         "name": "Automotive"
#                     }
#                 }
#             ],
#             "conversation_id": "1483796620294508546",
#             "created_at": "2022-01-19T13:40:56.000Z",
#             "entities": {
#                 "annotations": [
#                     {
#                         "end": 32,
#                         "normalized_text": "Corea",
#                         "probability": 0.892,
#                         "start": 28,
#                         "type": "Place"
#                     },
#                     {
#                         "end": 54,
#                         "normalized_text": "Samsung",
#                         "probability": 0.7398,
#                         "start": 48,
#                         "type": "Organization"
#                     },
#                     {
#                         "end": 84,
#                         "normalized_text": "Jap\u00f3n",
#                         "probability": 0.9348,
#                         "start": 80,
#                         "type": "Place"
#                     },
#                     {
#                         "end": 105,
#                         "normalized_text": "Toyota",
#                         "probability": 0.618,
#                         "start": 100,
#                         "type": "Organization"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "end": 14,
#                         "id": "847238444967313408",
#                         "start": 3,
#                         "username": "Mariafeck2"
#                     }
#                 ]
#             },
#             "id": "1483796620294508546",
#             "lang": "es",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 11
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1483779652330082304",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @Mariafeck2: Imag\u00ednate a Corea prohibiendo a Samsung exportar celulares. O a Jap\u00f3n prohibiendo a Toyota exportar coches para cuidar los\u2026"
#         },
#         {
#             "author_id": "191032928",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "1174344555111469057",
#                         "name": "Samsung Indonesia"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "10026364234",
#                         "name": "Samsung "
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10045298641",
#                         "name": "Samsung USA"
#                     }
#                 }
#             ],
#             "conversation_id": "1483796449108320257",
#             "created_at": "2022-01-19T13:40:15.000Z",
#             "entities": {
#                 "annotations": [
#                     {
#                         "end": 61,
#                         "normalized_text": "Samsung Health",
#                         "probability": 0.7522,
#                         "start": 48,
#                         "type": "Product"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "tuexpertomovil.com/2022/01/19/com\u2026",
#                         "end": 89,
#                         "expanded_url": "https://www.tuexpertomovil.com/2022/01/19/como-configurar-samsung-health-galaxy/",
#                         "start": 66,
#                         "url": "https://t.co/iX4g0HLuU4"
#                     }
#                 ]
#             },
#             "id": "1483796449108320257",
#             "lang": "es",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "tuexpertomovil",
#             "text": "Comienza una nueva vida practicando deporte con Samsung Health. \ud83d\udcaa https://t.co/iX4g0HLuU4"
#         },
#         {
#             "author_id": "104300358",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "1174344555111469057",
#                         "name": "Samsung Indonesia"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "10026364234",
#                         "name": "Samsung "
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Products created by Brands.  Examples: Ford Explorer, Apple iPhone.",
#                         "id": "48",
#                         "name": "Product"
#                     },
#                     "entity": {
#                         "id": "10045298641",
#                         "name": "Samsung USA"
#                     }
#                 }
#             ],
#             "conversation_id": "1483796433555836929",
#             "created_at": "2022-01-19T13:40:12.000Z",
#             "entities": {
#                 "annotations": [
#                     {
#                         "end": 61,
#                         "normalized_text": "Samsung Health",
#                         "probability": 0.7522,
#                         "start": 48,
#                         "type": "Product"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "tuexpertomovil.com/2022/01/19/com\u2026",
#                         "end": 89,
#                         "expanded_url": "https://www.tuexpertomovil.com/2022/01/19/como-configurar-samsung-health-galaxy/",
#                         "start": 66,
#                         "url": "https://t.co/rdn9KBFEwH"
#                     }
#                 ]
#             },
#             "id": "1483796433555836929",
#             "lang": "es",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
# ...
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1478164496342405120/F_9xV23h_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 134,
#                     "following_count": 159,
#                     "listed_count": 1,
#                     "tweet_count": 401
#                 },
#                 "url": "",
#                 "username": "MStradini",
#                 "verified": false
#             },
#             {
#                 "created_at": "2014-06-02T01:54:44.000Z",
#                 "description": "Soy insoportable. No me sigas.\nLa esperanza son los padres.\nEl saber no ocupa lugar. El no saber tampoco, pero se nota mas.",
#                 "id": "2540571728",
#                 "location": "Intransigente ambiguedad.",
#                 "name": "Lo que dijiste hizo mas pelotudos a todos.",
#                 "pinned_tweet_id": "1474989069327376387",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1478630556783067138/vEHZsCTE_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 361,
#                     "following_count": 575,
#                     "listed_count": 3,
#                     "tweet_count": 23406
#                 },
#                 "url": "",
#                 "username": "supermandelapc",
#                 "verified": false
#             },
#             {
#                 "created_at": "2013-03-23T02:06:19.000Z",
#                 "description": "La pastafrola es con membrillo\n- entrerriane - invierniste - modele de panze - ex- T! -",
#                 "id": "1290176389",
#                 "location": "Rep. Bananera de kirchneristan",
#                 "name": "PastafrolaFeroz\ud83e\udd67",
#                 "pinned_tweet_id": "1477799222141403138",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1483603689512357891/_LfUP8Tm_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 337,
#                     "following_count": 376,
#                     "listed_count": 1,
#                     "tweet_count": 34936
#                 },
#                 "url": "",
#                 "username": "pastafrolaFeroz",
#                 "verified": false
#             },
#             {
#                 "created_at": "2014-02-25T13:11:54.000Z",
#                 "description": "arIes, Aquarius & RomA \u2665    \u2652\ufe0f\ud83d\udc9e",
#                 "id": "2364901030",
#                 "name": "D a m i a n",
#                 "pinned_tweet_id": "1375432805291802624",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1365836390227988480/ArDgZtdr_normal.jpg",
#                 "protected": true,
#                 "public_metrics": {
#                     "followers_count": 290,
#                     "following_count": 730,
#                     "listed_count": 0,
#                     "tweet_count": 40703
#                 },
#                 "url": "",
#                 "username": "eightyvi",
#                 "verified": false
#             },
#             {
#                 "created_at": "2011-07-31T00:37:28.000Z",
#                 "description": "",
#                 "id": "345679585",
#                 "name": "OkaiboUry",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1181145031236882432/OPmbKp56_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 29,
#                     "following_count": 94,
#                     "listed_count": 0,
#                     "tweet_count": 6144
#                 },
#                 "url": "",
#                 "username": "OkaiboUry",
#                 "verified": false
#             },
#             {
#                 "created_at": "2021-05-31T03:11:47.000Z",
#                 "description": "",
#                 "id": "1399201878362177541",
#                 "name": "Gix Evans",
#                 "pinned_tweet_id": "1468003684260974605",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1481866024395972614/jieQH1mw_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 184,
#                     "following_count": 1439,
#                     "listed_count": 1,
#                     "tweet_count": 5989
#                 },
#                 "url": "",
#                 "username": "GixEvans",
#                 "verified": false
#             },
#             {
#                 "created_at": "2018-05-14T19:07:42.000Z",
#                 "description": "Les tir\u00e9 una constituci\u00f3n vanguardista y me devolvieron un panfleto comunista. John the Baptist Angry Alberdi",
#                 "id": "996104784880066560",
#                 "name": "Angry",
#                 "pinned_tweet_id": "1295708987875360769",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1412100599282294787/NakReQiV_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 4075,
#                     "following_count": 2701,
#                     "listed_count": 6,
#                     "tweet_count": 42158
#                 },
#                 "url": "",
#                 "username": "AngryAlberdi",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-06-08T14:47:49.000Z",
#                 "description": "Bienvenidos a la cuenta oficial de Samsung Espa\u00f1a. \nSi necesitas soporte t\u00e9cnico: https://t.co/15tNOojavj  de 9 a 20h. de lunes a viernes.",
#                 "entities": {
#                     "description": {
#                         "urls": [
#                             {
#                                 "display_url": "spr.ly/AtCliente",
#                                 "end": 105,
#                                 "expanded_url": "http://spr.ly/AtCliente",
#                                 "start": 82,
#                                 "url": "https://t.co/15tNOojavj"
#                             }
#                         ]
#                     },
#                     "url": {
#                         "urls": [
#                             {
#                                 "display_url": "samsung.com/es",
#                                 "end": 23,
#                                 "expanded_url": "http://www.samsung.com/es",
#                                 "start": 0,
#                                 "url": "https://t.co/F37TYsQmYM"
#                             }
#                         ]
#                     }
#                 },
#                 "id": "45579875",
#                 "location": "Espa\u00f1a",
#                 "name": "Samsung Espa\u00f1a",
#                 "pinned_tweet_id": "1478002207761043462",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1455453654966751237/HI45fBsH_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 312989,
#                     "following_count": 1271,
#                     "listed_count": 1246,
#                     "tweet_count": 67220
#                 },
#                 "url": "https://t.co/F37TYsQmYM",
#                 "username": "SamsungEspana",
#                 "verified": true
#             },
#             {
#                 "created_at": "2010-06-30T22:50:11.000Z",
#                 "description": "Simplemente conectado. Bloguero a tiempo parcial y vividor a tiempo completo. Apasionado del marketing social y de mi familia\ud83e\udd23\ud83e\udd23\ud83e\udd23",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "display_url": "elblogdelamigoinformatico.com",
#                                 "end": 23,
#                                 "expanded_url": "http://elblogdelamigoinformatico.com",
#                                 "start": 0,
#                                 "url": "https://t.co/8rDaSdWGWV"
#                             }
#                         ]
#                     }
#                 },
#                 "id": "161463629",
#                 "location": "Valencia, Spain",
#                 "name": "ElBlogDelAmigoInformatico\ud83c\udfc6\ud83d\udcaf",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1191116275159912449/tLPKKP0C_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 190,
#                     "following_count": 227,
#                     "listed_count": 3,
#                     "tweet_count": 37283
#                 },
#                 "url": "https://t.co/8rDaSdWGWV",
#                 "username": "josegisbert",
#                 "verified": false
#             },
#             {
#                 "created_at": "2020-05-05T21:06:37.000Z",
#                 "description": "Me gusta el metal, los videojuegos, adoro a mi familia",
#                 "id": "1257778677296910337",
#                 "name": "javiercio",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1483217311456714755/l8EMNoN9_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 21,
#                     "following_count": 255,
#                     "listed_count": 0,
#                     "tweet_count": 812
#                 },
#                 "url": "",
#                 "username": "javiercio4",
#                 "verified": false
#             },
#             {
#                 "created_at": "2021-02-20T22:12:56.000Z",
#                 "description": "Para entrar al canal de Telegram, escribe a este usuario o hazlo a partir del link de la web\ud83d\udc47 INFO Telegram: @CEO_CRYPTOTRADING",
#                 "entities": {
#                     "description": {
#                         "mentions": [
#                             {
#                                 "end": 127,
#                                 "start": 109,
#                                 "username": "CEO_CRYPTOTRADING"
#                             }
#                         ]
#                     },
#                     "url": {
#                         "urls": [
#                             {
#                                 "display_url": "cryptocapo.es/cuenta-de-memb\u2026",
#                                 "end": 23,
#                                 "expanded_url": "https://cryptocapo.es/cuenta-de-membresia/tu-perfil/",
#                                 "start": 0,
#                                 "url": "https://t.co/nf7BNuELvR"
#                             }
#                         ]
#                     }
#                 },
#                 "id": "1363250266821246977",
#                 "location": "Espa\u00f1a",
#                 "name": "CRYPTOCAPO\ud83e\udd20",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1473056248320954374/p03BNqBg_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 48525,
#                     "following_count": 637,
#                     "listed_count": 320,
#                     "tweet_count": 3617
#                 },
#                 "url": "https://t.co/nf7BNuELvR",
#                 "username": "CryptocapoOO",
#                 "verified": false
#             },
#             {
#                 "created_at": "2014-10-12T02:14:08.000Z",
#                 "description": "Deporte \u26bd\ud83c\udfc6\ud83c\udfc0\ud83d\udd1d\ud83d\udd1d\ud83d\udd1d  Gamer \ud83c\udfae Cine \ud83c\udfac M\u00fasica \ud83c\udfb5 Sonido bass \ud83c\udfa7 \ud83d\udd0a  Photo \ud83d\udcf7 vive tu d\u00eda \ud83d\udcc6  \u264b\ud83d\udd25luxury \ud83d\udd25\ud83d\udee3",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "display_url": "instagram.com/andresf_salgado",
#                                 "end": 23,
#                                 "expanded_url": "http://instagram.com/andresf_salgado",
#                                 "start": 0,
#                                 "url": "https://t.co/XeFQcl7IGl"
#                             }
#                         ]
#                     }
#                 },
#                 "id": "2824123179",
#                 "location": "Sincelejo, Colombia",
#                 "name": "ANDRESF_SALGADO",
#                 "pinned_tweet_id": "1248960219037786113",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1422194074040295427/yau__aP-_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 118,
#                     "following_count": 573,
#                     "listed_count": 1,
#                     "tweet_count": 4317
#                 },
#                 "url": "https://t.co/XeFQcl7IGl",
#                 "username": "andresf_salgado",
#                 "verified": false
#             },
#             {
#                 "created_at": "2010-08-31T21:40:38.000Z",
#                 "description": "Disfruta de lo mejor de Samsung. Si tienes preguntas, te ayudamos en el #726. Pol\u00edtica de protecci\u00f3n de datos aqu\u00ed: https://t.co/TjCwdZAjp1",
#                 "entities": {
#                     "description": {
#                         "urls": [
#                             {
#                                 "display_url": "bit.ly/2iqMELF",
#                                 "end": 139,
#                                 "expanded_url": "http://bit.ly/2iqMELF",
#                                 "start": 116,
#                                 "url": "https://t.co/TjCwdZAjp1"
#                             }
#                         ]
#                     },
#                     "url": {
#                         "urls": [
#                             {
#                                 "display_url": "samsung.com/co",
#                                 "end": 23,
#                                 "expanded_url": "http://www.samsung.com/co",
#                                 "start": 0,
#                                 "url": "https://t.co/5DgYaCrUVP"
#                             }
#                         ]
#                     }
#                 },
#                 "id": "185388944",
#                 "location": "Colombia",
#                 "name": "Samsung Colombia",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1278116423383089159/u2EmkrJr_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 282602,
#                     "following_count": 176,
#                     "listed_count": 308,
#                     "tweet_count": 22934
#                 },
#                 "url": "https://t.co/5DgYaCrUVP",
#                 "username": "SamsungCO",
#                 "verified": true
#             },
#             {
#                 "created_at": "2018-07-13T19:18:45.000Z",
#                 "description": "MBA ESEADE.\nLiberal de la Escuela Austriaca.\nNicole\u00f1o.\nCombatiente de la guerra \u00c9tica y cultural contra la izquierda que hace a\u00f1os se est\u00e1 librando.",
#                 "id": "1017850838507819009",
#                 "name": "Ruben Pujals",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1019944654089998336/0o5vSmrH_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 319,
#                     "following_count": 598,
#                     "listed_count": 0,
#                     "tweet_count": 11523
#                 },
#                 "url": "",
#                 "username": "PujalsRuben",
#                 "verified": false
#             }
#         ]
#     },
#     "meta": {
#         "newest_id": "1483798412088647689",
#         "next_token": "b26v89c19zqg8o3fpe46dtsyi4bdwo6j0airv09xwr7gd",
#         "oldest_id": "1483779925362491392",
#         "result_count": 100
#     }
# }

# %% [markdown]
# ### Vamos a quedarnos con los campos que necesitamos incluir en el dataframe final:
# - text  (el texto del tweet)
# - username (el autor del tweet)
# - created_at (fecha de creación del tweet)
# - followers_count (número de seguidores del autor del tweet)
# - retweet_count (número de retweets que ha tenido este tweet)
# - verified (si el tweet está verificado o no)

# %%
## para ver las claves del archivo json que nos hemos bajado
json_response.keys()
# Out:
# dict_keys(['data', 'includes', 'meta'])

# %%
json_response["includes"].keys()
# Out:
# dict_keys(['users', 'media', 'tweets', 'places'])

# %%
json_response["includes"]["users"][6]
# Out:
# {'url': '',
#  'verified': False,
#  'profile_image_url': 'https://pbs.twimg.com/profile_images/1437819084352131073/1QWpiExe_normal.jpg',
#  'id': '1076383362250690560',
#  'protected': False,
#  'public_metrics': {'followers_count': 5,
#   'following_count': 90,
#   'tweet_count': 176,
#   'listed_count': 0},
#  'location': 'Grasalandia :v',
#  'username': 'Oh_GRAN_JUEZ',
#  'name': 'EL_JUEZ',
#  'created_at': '2018-12-22T07:46:06.000Z',
#  'description': '💙💛💙🏆🇦🇷🔟'}

# %%
json_response["includes"]["users"][0]["username"]
# Out:
# 'rumiantee'

# %%
json_response["includes"]["users"][0]["verified"]
# Out:
# False

# %%
json_response["includes"]["users"][0]["public_metrics"]["followers_count"]
# Out:
# 521

# %%
json_response["data"][0].keys()
# Out:
# dict_keys(['conversation_id', 'reply_settings', 'possibly_sensitive', 'author_id', 'id', 'public_metrics', 'context_annotations', 'lang', 'source', 'entities', 'text', 'created_at'])

# %%
json_response["data"][0]["created_at"]
# Out:
# '2022-01-19T13:48:03.000Z'

# %%
json_response["data"][0]["public_metrics"]["retweet_count"]
# Out:
# 0

# %%
json_response["data"][0]["text"]
# Out:
# 'Oye pero ira a funcionar la ley de tallas? Si mal no estoy, había una norma que prohibía vender celulares sin cargador, y ahí esta Samsung y Apple haciéndolo, igual que la ley que prohibía vender celulares sin radio y también se venden xd'

# %% [markdown]
# ### Creamos archivos csv para cada una de las 2 keys del archivo json, y así almacenamos los datos
# Sucesivamente uniremos los 2 dataframes en uno final
#
# IMPORTANTE: una vez creado los 2 csv, los comentamos, ya que si no a cada vez que ejecutemos el notebook se añadirán las cabeceras de los csv

# %%
## aquí salvamos el response en json, pero NO nos sirve para nuestro analisis
## en el paso de la siguiente celda lo guardamos a csv
with open('../data/processed/data_ver.json', 'w') as f:
    json.dump(json_response, f)

# %%
# ## creamos el archivo csv para la key "data"  -->part_1

# # csvFile_part_1_ver = open("../data/processed/data_part_1_ver.csv", "a", newline="", encoding='utf-8')
# csvWriter_part_1_ver= csv.writer(csvFile_part_1_ver)

# %%
## creamos las cabeceras del archivo csv (vacio de momento) relativas a los datos que quiera guardar
## para la key "data"  -->part_1
# csvWriter_part_1_ver.writerow(['text', 'created_at', 'retweet_count'])
# csvFile_part_1_ver.close()

# %%
## creamos el archivo csv para la key "data"  -->part_2
# # csvFile_part_2_ver = open("../data/processed/data_part_2_ver.csv", "a", newline="", encoding='utf-8')
# csvWriter_part_2_ver = csv.writer(csvFile_part_2_ver)

# %%
### creamos las cabeceras del archivo csv (vacio de momento) relativas a los datos que quiera guardar
## para la key "data"  -->part_2
# csvWriter_part_2_ver.writerow(['username',  'followers_count', 'verified'])
# csvFile_part_2_ver.close()

# %% [markdown]
# ### ------------------------------

# %%
## creamos una función para añadir los campos necesarios del json al csv 
# cada vez que ejecutemos la celda de bajar tweets, se añadirán a este csv
def append_to_csv_part_1_ver(json_response, fileName):
    ''' 
    Añade los campos necesarios del json al csv
    cada vez se ejecute la celda de bajar tweets.
    Relativo a la clave ["data"] del json
    '''

    counter = 0

    #Abre o crea el target CSV file
    csvFile_part_1_ver = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter_part_1_ver = csv.writer(csvFile_part_1_ver)

    #bucle for para cada tweet relativo a la key "data" del json
    for tweet in json_response['data']:
        
        # 1. Texto del tweet
        text = tweet['text']

        # 3. Fecha y hora en la que se escribió el tweet
        created_at = dateutil.parser.parse(tweet['created_at'])

        # 4. Número de retweets del tweet
        retweet_count = tweet['public_metrics']['retweet_count']
        
        # Unimos todos los datos en una lista
        res = [text, created_at, retweet_count]

        # Añadimos los resultados al CSV
        csvWriter_part_1_ver.writerow(res)
        counter += 1


    # Cuando esté hecho, cerramos el csv
    csvFile_part_1_ver.close()

    # Imprimimos el número de tweets para esta iteración
    print("Número de tweets añadidos en esta request: ", counter)

# %%
## llamamos a la función para incluir las datos en el csv part_1
append_to_csv_part_1_ver(json_response, "../data/processed/data_part_1_ver.csv")
# Out:
# Número de tweets añadidos en esta request:  100

# %%
df_part_1_ver = pd.read_csv("../data/processed/data_part_1_ver.csv")

# %%
## creamos una función para añadir los campos necesarios del json al csv 
# cada vez que ejecutemos la celda de bajar tweets, se añadirán a este csv
def append_to_csv_part_2_ver(json_response, fileName):
    ''' 
    Añade los campos necesarios del json al csv
    cada vez se ejecute la celda de bajar tweets.
    Relativo a la clave ["includes"] del json
    '''

    counter = 0

    #Abre o crea el target CSV file
    csvFile_part_2_ver = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter_part_2_ver = csv.writer(csvFile_part_2_ver)

        
    #bucle for para cada tweet relativo a la key "includes" del json
    for tweet in json_response['includes']['users']:
        
        # 2. Username del autor del tweet
        username = tweet['username']
        
        # 5. Número de followers del autor del tweet
        followers_count = tweet['public_metrics']['followers_count']
        
        # 6. Indica si el tweet está verificado o no
        verified = tweet['verified']


        # Unimos todos los datos en una lista
        res = [username, followers_count, verified]
        
        # Añadimos los resultados al CSV
        csvWriter_part_2_ver.writerow(res)
        counter += 1

    # Cuando esté hecho, cerramos el csv
    csvFile_part_2_ver.close()

    # Imprimimos el número de tweets para esta iteración
    print("Número de tweets añadidos en esta request: ", counter)

# %%
## llamamos a la función para incluir las datos en el csv part_2
append_to_csv_part_2_ver(json_response, "../data/processed/data_part_2_ver.csv")
# Out:
# Número de tweets añadidos en esta request:  121

# %%
df_part_2_ver = pd.read_csv("../data/processed/data_part_2_ver.csv")

# %%
## creamos una columna temporal para mergear los 2 csv
import numpy as np
df_part_1_ver["temporal"] = np.arange(0, len(df_part_1_ver))
df_part_2_ver["temporal"] = np.arange(0, len(df_part_2_ver))

# %%
df_final_ver = pd.merge(df_part_1_ver,df_part_2_ver, how = "inner",  on=["temporal"])
df_final_ver = df_final_ver.drop("temporal", axis = 1)

# %%
## aplicamos el drop duplicates por si hubiera filas duplicadas
df_final_ver.drop_duplicates()

# %%
## guardo el dataframe final en un csv 
## lo guardo en la ruta de la carpeta con la API que vamos a crear para el proyecto
df_final_ver.to_csv("../API_twitter/tweets_ver.csv", index=False)

# %%
## lo abro para comprobar que esté bien
df_ver = pd.read_csv("../API_twitter/tweets_ver.csv")
df_ver
# Out:
#                                                                                                                                                                                                                                                                                                             text  \
# 0                                                                                                                                                                   RT @LuisGyG: 70 ciudadanos de Coreal del Sur (incluidos algunos representantes de Samsung y la fabricante de chips SK Hynix) dieron positiv…
# 1                                                                                                                                                        @anabel0944 Xa a mi gusto el iphone pa grabar videos en 4k, pero me gusta mas para fotos el s21 ultra ahora ese celular samsung puedes grabar 4k y 8k🥺😍
# 2                                                                                                                                                                    RT @hyyunmei: K-Stay: las típicas primas milipilis que tiene todo iPhone, Gucci, todo re caro y le pasas un samsung o motorola y empieza a…
# 3   70 ciudadanos de Coreal del Sur (incluidos algunos representantes de Samsung y la fabricante de chips SK Hynix) dieron positivo a #COVID tras asistir al #CES2022 en Las Vegas, según @Reuters. La CTA, organizadora del CES, no pudo confirmar el número de positivos en el evento. https://t.co/IfbAhsgesN
# 4                                                          @meinOddity si tiene Samsung te sale una app llamada game launcher, ahí deben de estar todos los juegos descargados que tengas, abajo del icon del juego aparace una opción llamada "detalles", y en esa te dice cuantas horas vas jugando cada juego
# ..                                                                                                                                                                                                                                                                                                           ...
# 95                                                                                                                                                                  RT @SaraOdemiOdeck: Es poco probable que lo termine a si que lo comparto asi 😆 Mi primera ilustracion hecha completamente en mi samsung tab…
# 96                                                                                                                                                                                                        @xJulio89x @ParamountPlusLA Pues yo tengo Samsung y no me aparece la aplicación, es de modelo reciente
# 97                                                                                                                                                                                                Samsung anunció nuevas funciones y tecnología para los hogares en CES 2022 @SamsungArg https://t.co/F3mZlOWvrR
# 98                                                                                                                                                                                                   Hoy lo lograré.\n\nLo juro.\n\nLo que sea por twittear desde un SAMSUNG SmartDildo™ https://t.co/BmwYTFhrR3
# 99                                                                                                          Samsung EVO Select 128GB, microSD, A2, V30, 130 MB/s, FHD, 4K UHD, tarjeta de memoria con adaptador para Smartphone, Tablet, Cámara de Acción, Drone o Notebook (MB-ME128KA) https://t.co/tqlQWEX06f
#
#                    created_at  retweet_count         username  \
# 0   2022-01-14 14:24:59+00:00              1   JoiaribElnatan
# 1   2022-01-14 14:24:35+00:00              0          LuisGyG
# 2   2022-01-14 14:23:47+00:00              2          GiXnoxD
# 3   2022-01-14 14:22:48+00:00              1       anabel0944
# 4   2022-01-14 14:22:46+00:00              0          MarSt4y
# ..                        ...            ...              ...
# 95  2022-01-14 12:36:14+00:00              3           csnwz_
# 96  2022-01-14 12:34:00+00:00              0         m__casti
# 97  2022-01-14 12:33:10+00:00              0   botxboxseriesx
# 98  2022-01-14 12:33:01+00:00              0        chalioDMX
# 99  2022-01-14 12:32:27+00:00              0  liverpoolmexico
#
#     followers_count  verified
# 0             16056     False
# 1             64264      True
# 2               416     False
# 3               180     False
# 4                16     False
# ..              ...       ...
# 95             3248     False
# 96             3647     False
# 97             1568     False
# 98               79     False
# 99           713921      True
#
# [100 rows x 6 columns]
